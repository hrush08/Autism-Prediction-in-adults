# %% [markdown]
# # Autism Prediction on Adults

# %% [markdown]
# Data Exploration

# %%
# For adult dataset
import arff
import pandas as pd
# Load arff file
with open('Autism-Adult-Data.arff') as f:
    dataset = arff.load(f)
# Convert to DataFrame
adult = pd.DataFrame(dataset['data'], columns=[attr[0] for attr in dataset['attributes']])
# Display 
adult
# Out:
#     A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0          1        1        1        1        0        0        1        1
# 1          1        1        0        1        0        0        0        1
# 2          1        1        0        1        1        0        1        1
# 3          1        1        0        1        0        0        1        1
# 4          1        0        0        0        0        0        0        1
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 699        0        1        0        1        1        0        1        1
# 700        1        0        0        0        0        0        0        1
# 701        1        0        1        1        1        0        1        1
# 702        1        0        0        1        1        0        1        0
# 703        1        0        1        1        1        0        1        1
#
# ...

# %%
# To know the number of rows and columns in a dataframe
adult.shape
# Out:
# (704, 21)

# %%
# To display all the columns
pd.set_option('display.max_columns',None)

# %%
# The dataset contains data like ? and I am replacing those values with null by using numpy library
import numpy as np
adult = adult.replace('?', np.nan)

# %%
# To know how many null values present in the dataset and the datatype of each column
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   A1_Score         704 non-null    object
#  1   A2_Score         704 non-null    object
#  2   A3_Score         704 non-null    object
#  3   A4_Score         704 non-null    object
#  4   A5_Score         704 non-null    object
#  5   A6_Score         704 non-null    object
#  6   A7_Score         704 non-null    object
#  7   A8_Score         704 non-null    object
#  8   A9_Score         704 non-null    object
#  9   A10_Score        704 non-null    object
#  10  age              702 non-null    float64
#  11  gender           704 non-null    object
#  12  ethnicity        609 non-null    object
#  13  jundice          704 non-null    object
#  14  austim           704 non-null    object
#  15  contry_of_res    704 non-null    object
# ...

# %%
# To know what type of data is the dataset is storing
for col in adult.columns:
    print(col,adult[col].unique())
    print("-"*50)
# Out:
# A1_Score ['1' '0']
# --------------------------------------------------
# A2_Score ['1' '0']
# --------------------------------------------------
# A3_Score ['1' '0']
# --------------------------------------------------
# A4_Score ['1' '0']
# --------------------------------------------------
# A5_Score ['0' '1']
# --------------------------------------------------
# A6_Score ['0' '1']
# --------------------------------------------------
# A7_Score ['1' '0']
# --------------------------------------------------
# A8_Score ['1' '0']
# --------------------------------------------------
# A9_Score ['0' '1']
# --------------------------------------------------
# A10_Score ['0' '1']
# --------------------------------------------------
# age [ 26.  24.  27.  35.  40.  36.  17.  64.  29.  33.  18.  31.  30.  34.
#   38.  42.  43.  48.  37.  55.  50.  53.  20.  28.  21. 383.  47.  32.
#   44.  nan  19.  58.  45.  22.  39.  25.  23.  54.  60.  41.  46.  56.
#   61.  59.  52.  49.  51.]
# ...

# %%
adult.describe()
# Out:
#               age      result
# count  702.000000  704.000000
# mean    29.698006    4.875000
# std     16.507465    2.501493
# min     17.000000    0.000000
# 25%     21.000000    3.000000
# 50%     27.000000    4.000000
# 75%     35.000000    7.000000
# max    383.000000   10.000000

# %%
# To know count of both 'yes' and 'no' in the target variable
adult['Class/ASD'].value_counts()
# Out:
# Class/ASD
# NO     515
# YES    189
# Name: count, dtype: int64

# %%
# To extract all the column names
adult.columns
# Out:
# Index(['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score',
#        'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'age', 'gender',
#        'ethnicity', 'jundice', 'austim', 'contry_of_res', 'used_app_before',
#        'result', 'age_desc', 'relation', 'Class/ASD'],
#       dtype='object')
